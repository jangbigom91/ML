# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score
from sklearn.metrics import f1_score, confusion_matrix, precision_recall_curve, roc_curve
from sklearn.preprocessing import StandardScaler

columns = ['Age','Workclass','fnlgwt','Education','Education num','Marital Status',
           'Occupation','Relationship','Race','Sex','Capital Gain','Capital Loss',
           'Hours/Week','Native country','Income']

adult_data_df = pd.read_csv('./adult.data_converted.csv', names=columns)
adult_data_df.head(5)
# Out:
#    Age         Workclass  fnlgwt  Education  Education num  \
# 0  age        work-class  fnlwgt  education  education-num
# 1   39         State-gov   77516  Bachelors             13
# 2   50  Self-emp-not-inc   83311  Bachelors             13
# 3   38           Private  215646    HS-grad              9
# 4   53           Private  234721       11th              7
#
#        Marital Status         Occupation   Relationship   Race   Sex  \
# 0      marital-status         occupation   relationship   race   sex
# 1       Never-married       Adm-clerical  Not-in-family  White  Male
# 2  Married-civ-spouse    Exec-managerial        Husband  White  Male
# 3            Divorced  Handlers-cleaners  Not-in-family  White  Male
# 4  Married-civ-spouse  Handlers-cleaners        Husband  Black  Male
#
#    Capital Gain  Capital Loss      Hours/Week  Native country  \
# 0  capital-gain  capital-loss  hours-per-week  native-country
# 1          2174             0              40   United-States
# ...

# %%
adult_data_df.shape
# Out:
# (32563, 15)

# %%
adult_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32563 entries, 0 to 32562
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32562 non-null  object
#  1   Workclass       30726 non-null  object
#  2   fnlgwt          32562 non-null  object
#  3   Education       32562 non-null  object
#  4   Education num   32562 non-null  object
#  5   Marital Status  32562 non-null  object
#  6   Occupation      30719 non-null  object
#  7   Relationship    32562 non-null  object
#  8   Race            32562 non-null  object
#  9   Sex             32562 non-null  object
#  10  Capital Gain    32562 non-null  object
#  11  Capital Loss    32562 non-null  object
#  12  Hours/Week      32562 non-null  object
#  13  Native country  31979 non-null  object
#  14  Income          32562 non-null  object
# dtypes: object(15)
# memory usage: 3.7+ MB

# %%
adult_data_df['Age'].fillna('N', inplace=True)
adult_data_df['Workclass'].fillna('N', inplace=True)
adult_data_df['fnlgwt'].fillna('N', inplace=True)
adult_data_df['Education'].fillna('N', inplace=True)
adult_data_df['Education num'].fillna('N', inplace=True)
adult_data_df['Marital Status'].fillna('N', inplace=True)
adult_data_df['Occupation'].fillna('N', inplace=True)
adult_data_df['Relationship'].fillna('N', inplace=True)
adult_data_df['Race'].fillna('N', inplace=True)
adult_data_df['Sex'].fillna('N', inplace=True)
adult_data_df['Capital Gain'].fillna('N', inplace=True)
adult_data_df['Capital Loss'].fillna('N', inplace=True)
adult_data_df['Hours/Week'].fillna('N', inplace=True)
adult_data_df['Native country'].fillna('N', inplace=True)
adult_data_df['Income'].fillna('N', inplace=True)

# %%
adult_data_df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# fnlgwt            0
# Education         0
# Education num     0
# Marital Status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital Gain      0
# Capital Loss      0
# Hours/Week        0
# Native country    0
# Income            0
# dtype: int64

# %%
adult_data_df.dropna().head()
# Out:
#    Age         Workclass  fnlgwt  Education  Education num  \
# 0  age        work-class  fnlwgt  education  education-num
# 1   39         State-gov   77516  Bachelors             13
# 2   50  Self-emp-not-inc   83311  Bachelors             13
# 3   38           Private  215646    HS-grad              9
# 4   53           Private  234721       11th              7
#
#        Marital Status         Occupation   Relationship   Race   Sex  \
# 0      marital-status         occupation   relationship   race   sex
# 1       Never-married       Adm-clerical  Not-in-family  White  Male
# 2  Married-civ-spouse    Exec-managerial        Husband  White  Male
# 3            Divorced  Handlers-cleaners  Not-in-family  White  Male
# 4  Married-civ-spouse  Handlers-cleaners        Husband  Black  Male
#
#    Capital Gain  Capital Loss      Hours/Week  Native country  \
# 0  capital-gain  capital-loss  hours-per-week  native-country
# 1          2174             0              40   United-States
# ...

# %%
adult_data_df = pd.read_csv('./adult.data_converted.csv')

y_adult_data_df = adult_data_df['Age']
X_adult_data_df = adult_data_df.drop('age')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\ad\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-072c6c59c3bb> in <module>
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(adult_data_df, adult_data_df, test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

dt_clf = DecisionTreeClassifier(random_state=11)
rf_clf = RandomForestClassifier(random_state=11)
lr_clf = LogisticRegression()

dt_clf.fit(X_train, y_train)
dt_pred = dt_clf.predict(X_test)
print('DecisionTreeClassifier 정확도 : {0:.4f}'.format(accuracy_score(y_test, dt_pred)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-59c0f44d0d9a> in <module>
#       8 lr_clf = LogisticRegression()
#       9
# ---> 10 dt_clf.fit(X_train, y_train)
#      11 dt_pred = dt_clf.predict(X_test)
#      12 print('DecisionTreeClassifier 정확도 : {0:.4f}'.format(accuracy_score(y_test, dt_pred)))
#
# c:\users\ad\appdata\local\programs\python\python38\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     896         """
#     897
# --> 898         super().fit(
#     899             X, y,
#     900             sample_weight=sample_weight,
#
# c:\users\ad\appdata\local\programs\python\python38\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     154             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
# ...
